# %%
# !uv run inv fetch-weather --endpoint forecast --latitude -34.603722 --longitude -58.381592
# Out:
# Metadata:
#  {'latitude': -34.75, 'longitude': -58.375, 'generationtime_ms': 0.07581710815429688, 'utc_offset_seconds': 0, 'timezone': 'GMT', 'timezone_abbreviation': 'GMT', 'elevation': 18.0, 'hourly_units': {'time': 'iso8601', 'temperature_2m': '°C', 'precipitation': 'mm', 'windspeed_10m': 'km/h'}}
# Data:
#                   time  temperature_2m  ...  latitude  longitude
# 0    2025-11-26T00:00            22.6  ...    -34.75    -58.375
# 1    2025-11-26T01:00            21.6  ...    -34.75    -58.375
# 2    2025-11-26T02:00            20.9  ...    -34.75    -58.375
# 3    2025-11-26T03:00            20.3  ...    -34.75    -58.375
# 4    2025-11-26T04:00            19.9  ...    -34.75    -58.375
# ..                ...             ...  ...       ...        ...
# 163  2025-12-02T19:00            27.5  ...    -34.75    -58.375
# 164  2025-12-02T20:00            26.4  ...    -34.75    -58.375
# 165  2025-12-02T21:00            25.3  ...    -34.75    -58.375
# ...
